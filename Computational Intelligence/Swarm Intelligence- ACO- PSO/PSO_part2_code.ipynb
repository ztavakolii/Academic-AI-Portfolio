# %% [markdown]
# ## import package and libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %% [markdown]
# # hyperparameter tuning of a neural network using PSO

# %% [markdown]
# ## Load MNIST and preprocess

# %%
(X_train_full, y_train_full), _ = tf.keras.datasets.mnist.load_data()
X = X_train_full.reshape(-1, 28*28) / 255.0
y = to_categorical(y_train_full)

# Use only 3000 samples for speed
X_small, y_small = X[:3000], y[:3000]
X_train, X_val, y_train, y_val = train_test_split(X_small, y_small, test_size=0.2, random_state=42)

# %%
def decode_particle(p):
    neurons = [int(p[0]), int(p[1]), int(p[2])]
    activation = ['relu', 'tanh', 'sigmoid'][int(p[3])]
    dropout = float(p[4])
    return neurons, activation, dropout

# %% [markdown]
# ## Define the fitness function for PSO

# %%
def fitness(particle):
    neurons, activation, dropout = decode_particle(particle)

    # TODO: Build a Sequential model with 3 hidden layers
    # TODO: Train for 3 epoch on X_train, evaluate on X_val
    # TODO: Return -val_accuracy (maximize accuracy)
    model=Sequential([Dense(neurons[0],activation=activation,input_shape=(784,)),
                      Dropout(dropout),
                      Dense(neurons[1],activation=activation),
                      Dropout(dropout),
                      Dense(neurons[2],activation=activation),
                      Dense(10,activation='softmax')])

    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    model.fit(X_train,y_train,epochs=3,batch_size=64)
    val_loss,val_accuracy=model.evaluate(X_val,y_val)

    return  -val_accuracy

# %% [markdown]
# ## Set PSO hyperparameters

# %%
# TODO: PSO hyperparameters
n_particles = 15
n_iterations = 10
w, c1, c2 = 0.7,1.5,1.5

bounds = np.array([
    [32, 256],
    [32, 256],
    [16, 128],
    [0, 2],
    [0.0, 0.5]
])

# TODO: PSO setup
positions = np.random.uniform(low=bounds[:,0],high=bounds[:,1],size=(n_particles,5))
velocities =np.zeros((n_particles,5))
pbest = positions.copy()
pbest_fitness = np.array([fitness(p) for p in positions])
gbest = pbest[np.argmin(pbest_fitness)]
gbest_fitness = pbest_fitness[np.argmin(pbest_fitness)]
history = [gbest_fitness]
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.4675 - loss: 1.6400
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8300 - loss: 0.5834
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8852 - loss: 0.4160
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8852 - loss: 0.3617
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4851 - loss: 1.6814
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8030 - loss: 0.8629
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8603 - loss: 0.6456
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8628 - loss: 0.5125
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5114 - loss: 1.5016
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8582 - loss: 0.5102
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9021 - loss: 0.3585
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9000 - loss: 0.3318
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 66ms/step - accuracy: 0.2989 - loss: 2.0203
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7042 - loss: 0.9419
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8165 - loss: 0.5773
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8805 - loss: 0.3710
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5565 - loss: 1.5904
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8807 - loss: 0.6958
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8923 - loss: 0.5308
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9068 - loss: 0.4585
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.3568 - loss: 1.9339
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7774 - loss: 0.7140
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8645 - loss: 0.4294
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9129 - loss: 0.3046
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4945 - loss: 1.6805
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8556 - loss: 0.5812
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8878 - loss: 0.4002
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9095 - loss: 0.3434
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.3658 - loss: 1.8915
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7398 - loss: 0.9776
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8110 - loss: 0.7343
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8603 - loss: 0.4895
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - accuracy: 0.5497 - loss: 1.4053
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8830 - loss: 0.3968
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9052 - loss: 0.3097
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9034 - loss: 0.3337
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.2362 - loss: 2.1333
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6231 - loss: 1.2071
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7279 - loss: 0.8308
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8540 - loss: 0.4450
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.3859 - loss: 1.8819
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7757 - loss: 0.8210
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8560 - loss: 0.5558
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8654 - loss: 0.3909
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.5034 - loss: 1.6426
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - loss: 0.8116
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8764 - loss: 0.6378
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8789 - loss: 0.5102
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.3424 - loss: 1.9021
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7879 - loss: 0.7703
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8238 - loss: 0.5845
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8904 - loss: 0.3569
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.2772 - loss: 2.0364
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7073 - loss: 0.9186
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8017 - loss: 0.6192
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8818 - loss: 0.3492
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.3080 - loss: 1.9975
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7307 - loss: 0.8627
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8327 - loss: 0.5343
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8997 - loss: 0.3384

# %% [markdown]
# ## PSO main loop

# %%
for t in range(n_iterations):
    for i in range(n_particles):
        r1 = np.random.rand()
        r2 = np.random.rand()

        #TODO: Update velocity
        velocities[i] = w*velocities[i]+c1*r1*(pbest[i]-positions[i])+c2*r2*(gbest-positions[i])

        #TODO: Update position
        positions[i] = positions[i]+velocities[i]
        positions[i] = np.clip(positions[i], bounds[:, 0], bounds[:, 1])
        fitness_ = fitness(positions[i])

        # TODO: Update personal best (p_best and p_best_scores) if new position is better
        if fitness_ < pbest_fitness[i]:
            pbest_fitness[i]=fitness_
            pbest[i]=positions[i]


        # TODO: Update global best (g_best and g_best_score) if new p_best is better than g_best
        if fitness_ < gbest_fitness:
                gbest_fitness=fitness_
                gbest=positions[i]


    history.append(gbest_fitness)
# Out:
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.4658 - loss: 1.7408
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8391 - loss: 0.6187
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8964 - loss: 0.3988
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9113 - loss: 0.3435
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.4777 - loss: 1.6686
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8522 - loss: 0.6131
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8907 - loss: 0.4517
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8987 - loss: 0.3701
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5364 - loss: 1.4634
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8673 - loss: 0.5103
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.3492
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8960 - loss: 0.3426
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.2665 - loss: 2.1079
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6806 - loss: 1.0233
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8051 - loss: 0.6159
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8880 - loss: 0.3707
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.4257 - loss: 1.8168
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8275 - loss: 0.6747
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.4808
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8686 - loss: 0.4293
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4511 - loss: 1.8018
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8412 - loss: 0.6955
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8922 - loss: 0.4337
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8874 - loss: 0.3817
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.4557 - loss: 1.7180
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8287 - loss: 0.6407
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8995 - loss: 0.4097
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9050 - loss: 0.3392
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - accuracy: 0.4270 - loss: 1.7631
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8216 - loss: 0.7229
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8763 - loss: 0.5132
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8789 - loss: 0.4048
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5299 - loss: 1.5065
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8728 - loss: 0.4471
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9194 - loss: 0.2913
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9258 - loss: 0.2775
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.3179 - loss: 1.9455
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7626 - loss: 0.7550
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8569 - loss: 0.4892
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8736 - loss: 0.3616
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5645 - loss: 1.4030
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8921 - loss: 0.3818
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9197 - loss: 0.2745
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9085 - loss: 0.2908
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5464 - loss: 1.5316
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8622 - loss: 0.5572
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9009 - loss: 0.3884
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9156 - loss: 0.3188
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5076 - loss: 1.5610
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8795 - loss: 0.4444
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9067 - loss: 0.3413
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.9119 - loss: 0.3114
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.5408 - loss: 1.5545
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8882 - loss: 0.4250
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9175 - loss: 0.2912
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9081 - loss: 0.3180
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5212 - loss: 1.5191
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8756 - loss: 0.4395
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9107 - loss: 0.2942
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8968 - loss: 0.3059
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5161 - loss: 1.6045
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8805 - loss: 0.4496
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9161 - loss: 0.2999
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9013 - loss: 0.3064
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5251 - loss: 1.5461
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8597 - loss: 0.4723
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9015 - loss: 0.3441
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9126 - loss: 0.2946
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.5420 - loss: 1.5100
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8598 - loss: 0.4642
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9137 - loss: 0.3168
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9184 - loss: 0.2995
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5614 - loss: 1.3984
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8729 - loss: 0.4388
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9244 - loss: 0.2611
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8915 - loss: 0.3229
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5767 - loss: 1.4834
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8736 - loss: 0.4509
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9243 - loss: 0.2873
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9079 - loss: 0.3086
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.1035 - loss: 2.3935
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1691 - loss: 2.2687
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4246 - loss: 2.1907
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4753 - loss: 2.0900
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5570 - loss: 1.4578
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8627 - loss: 0.4472
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9105 - loss: 0.3054
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9266 - loss: 0.2954
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5322 - loss: 1.4717
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8787 - loss: 0.4199
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9114 - loss: 0.2841
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9005 - loss: 0.3199
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.5333 - loss: 1.4890
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8680 - loss: 0.4284
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8950 - loss: 0.3566
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9122 - loss: 0.2871
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5322 - loss: 1.4885
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8819 - loss: 0.4059
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9128 - loss: 0.2828
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.8968 - loss: 0.3445
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.5901 - loss: 1.3309
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8850 - loss: 0.3889
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9397 - loss: 0.2360
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8977 - loss: 0.3125
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4916 - loss: 1.6378
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8610 - loss: 0.5065
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9089 - loss: 0.3268
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9005 - loss: 0.3563
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.5054 - loss: 1.6063
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8648 - loss: 0.4722
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9130 - loss: 0.3080
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9051 - loss: 0.3087
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.1136 - loss: 2.3407
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.1762 - loss: 2.2516
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4310 - loss: 2.0961
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4572 - loss: 1.8794
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.5559 - loss: 1.4477
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9017 - loss: 0.3558
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.2474
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9193 - loss: 0.2876
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5491 - loss: 1.5242
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8937 - loss: 0.4119
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9165 - loss: 0.2910
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9092 - loss: 0.2817
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.5145 - loss: 1.6231
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8598 - loss: 0.4776
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8978 - loss: 0.3375
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8997 - loss: 0.3314
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.4772 - loss: 1.6523
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8324 - loss: 0.5512
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9075 - loss: 0.3516
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8899 - loss: 0.3448
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.4893 - loss: 1.5858
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8660 - loss: 0.4726
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8977 - loss: 0.3660
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9152 - loss: 0.3101
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5871 - loss: 1.3561
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8761 - loss: 0.4076
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9212 - loss: 0.2697
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9155 - loss: 0.2787
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.3112 - loss: 2.0001
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7566 - loss: 0.7470
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8628 - loss: 0.4642
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9139 - loss: 0.3025
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5584 - loss: 1.4150
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8780 - loss: 0.4113
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9108 - loss: 0.3114
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9033 - loss: 0.3110
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5741 - loss: 1.4388
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8762 - loss: 0.4001
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9296 - loss: 0.2629
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9115 - loss: 0.2893
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.5488 - loss: 1.4423
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8667 - loss: 0.4611
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9109 - loss: 0.3274
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9200 - loss: 0.2780
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5063 - loss: 1.5512
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8674 - loss: 0.4407
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9076 - loss: 0.3019
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9072 - loss: 0.3163
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.4969 - loss: 1.5729
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8497 - loss: 0.5088
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8906 - loss: 0.3529
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9115 - loss: 0.2930
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.5337 - loss: 1.5551
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8648 - loss: 0.4450
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9168 - loss: 0.2994
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.8936 - loss: 0.3153
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5438 - loss: 1.5015
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8804 - loss: 0.4512
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9184 - loss: 0.2771
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9085 - loss: 0.3059
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.5066 - loss: 1.5665
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.4844
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.3155
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9114 - loss: 0.2990
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5242 - loss: 1.5329
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8910 - loss: 0.4032
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.2927
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9153 - loss: 0.2979
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5016 - loss: 1.5873
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8582 - loss: 0.5072
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9015 - loss: 0.3385
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8974 - loss: 0.3321
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4651 - loss: 1.7168
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8402 - loss: 0.5239
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8946 - loss: 0.3543
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8940 - loss: 0.3559
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5416 - loss: 1.4870
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8923 - loss: 0.4126
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9151 - loss: 0.2942
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9073 - loss: 0.3253
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5133 - loss: 1.5518
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8618 - loss: 0.4730
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9176 - loss: 0.2985
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9075 - loss: 0.3052
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5627 - loss: 1.4292
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8688 - loss: 0.4291
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9075 - loss: 0.2979
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9171 - loss: 0.2812
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.3091 - loss: 1.9952
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7527 - loss: 0.7901
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8412 - loss: 0.4982
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9068 - loss: 0.2978
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.5261 - loss: 1.4791
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8671 - loss: 0.4355
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9187 - loss: 0.3012
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9161 - loss: 0.3058
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5348 - loss: 1.5006
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8798 - loss: 0.4208
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9224 - loss: 0.2891
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9130 - loss: 0.2884
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5625 - loss: 1.4464
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8605 - loss: 0.4546
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9005 - loss: 0.3210
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8976 - loss: 0.3034
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5152 - loss: 1.5412
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8628 - loss: 0.4588
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9032 - loss: 0.3130
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9234 - loss: 0.2939
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.2774 - loss: 2.0970
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6902 - loss: 0.9902
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8028 - loss: 0.6217
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8789 - loss: 0.3507
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.5205 - loss: 1.4992
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8659 - loss: 0.4557
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8991 - loss: 0.3434
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9244 - loss: 0.2909
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5321 - loss: 1.4920
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8674 - loss: 0.4452
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9192 - loss: 0.2881
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9128 - loss: 0.2768
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.5816 - loss: 1.3980
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8883 - loss: 0.4132
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9183 - loss: 0.2888
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9237 - loss: 0.2756
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5477 - loss: 1.4882
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8723 - loss: 0.4343
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.2945
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9134 - loss: 0.3185
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.4817 - loss: 1.6347
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8593 - loss: 0.4841
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9224 - loss: 0.3012
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9080 - loss: 0.3235
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.5266 - loss: 1.5365
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8576 - loss: 0.5014
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9064 - loss: 0.3367
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9168 - loss: 0.2928
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 21/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4426 - loss: 1.7880 Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9081 - loss: 0.3343
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.8935 - loss: 0.3152
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.5322 - loss: 1.4840
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8768 - loss: 0.4380
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9014 - loss: 0.3482
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9015 - loss: 0.3070
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.4909 - loss: 1.5789
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8522 - loss: 0.4685
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9095 - loss: 0.3270
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9112 - loss: 0.3120
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5725 - loss: 1.4444
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8809 - loss: 0.4139
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9202 - loss: 0.2780
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9156 - loss: 0.2960
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.5392 - loss: 1.5129
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8637 - loss: 0.4626
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9041 - loss: 0.3265
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9107 - loss: 0.3074
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5316 - loss: 1.4786
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8758 - loss: 0.4338
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9030 - loss: 0.3219
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9101 - loss: 0.3061
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5294 - loss: 1.5243
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8756 - loss: 0.4751
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9136 - loss: 0.3143
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9207 - loss: 0.3085
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.5646 - loss: 1.4916
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8726 - loss: 0.4017
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9251 - loss: 0.2838
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8902 - loss: 0.3309
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.4349 - loss: 1.7360
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8292 - loss: 0.6138
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8742 - loss: 0.4263
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9195 - loss: 0.3341
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.5598 - loss: 1.4002
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8805 - loss: 0.4462
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9174 - loss: 0.3011
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9029 - loss: 0.3193
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - accuracy: 0.5049 - loss: 1.5731
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8552 - loss: 0.5230
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9020 - loss: 0.3637
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.8845 - loss: 0.3385
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8255 - loss: 0.5713
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8789 - loss: 0.3855
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9108 - loss: 0.2794
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.5212 - loss: 1.5185
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8733 - loss: 0.4540
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9013 - loss: 0.3453
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.9165 - loss: 0.2998
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5501 - loss: 1.4784
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8804 - loss: 0.4295
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9190 - loss: 0.2757
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9016 - loss: 0.3011
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5374 - loss: 1.4933
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8874 - loss: 0.4427
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9037 - loss: 0.3274
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8931 - loss: 0.3218
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.5444 - loss: 1.4402
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8690 - loss: 0.4428
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9114 - loss: 0.2971
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8994 - loss: 0.3293
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.5519 - loss: 1.4759
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8746 - loss: 0.4428
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.3128
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8983 - loss: 0.2854
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - accuracy: 0.4965 - loss: 1.5424
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8492 - loss: 0.4895
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9081 - loss: 0.3312
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.8806 - loss: 0.3047
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5507 - loss: 1.4546
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8574 - loss: 0.4612
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9183 - loss: 0.3061
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8878 - loss: 0.3425
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.4307 - loss: 1.8241
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7841 - loss: 0.9345
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8321 - loss: 0.7439
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8434 - loss: 0.5614
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - accuracy: 0.5148 - loss: 1.5551
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8596 - loss: 0.4944
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8994 - loss: 0.3479
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8977 - loss: 0.3285
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.5480 - loss: 1.5571
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8897 - loss: 0.4528
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9142 - loss: 0.3336
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9124 - loss: 0.3186
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.4989 - loss: 1.5824
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8607 - loss: 0.4878
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9096 - loss: 0.3214
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9023 - loss: 0.3114
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5492 - loss: 1.4369
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8684 - loss: 0.4628
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9155 - loss: 0.3039
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9220 - loss: 0.3055
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5320 - loss: 1.4992
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8715 - loss: 0.4529
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9212 - loss: 0.3023
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.8984 - loss: 0.3245
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.5428 - loss: 1.4654
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8805 - loss: 0.3949
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.2909
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9182 - loss: 0.3198
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.4193 - loss: 1.8471
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8231 - loss: 0.5414
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8865 - loss: 0.3649
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9068 - loss: 0.3032
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - accuracy: 0.5346 - loss: 1.4723
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8641 - loss: 0.4672
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9074 - loss: 0.3467
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9243 - loss: 0.2856
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5652 - loss: 1.4492
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8829 - loss: 0.3986
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9125 - loss: 0.2953
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.9057 - loss: 0.3019
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5195 - loss: 1.5576
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8559 - loss: 0.4720
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9138 - loss: 0.3163
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9145 - loss: 0.3014
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 65ms/step - accuracy: 0.5140 - loss: 1.5865
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8813 - loss: 0.4476
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9177 - loss: 0.3318
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9098 - loss: 0.3112
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.5101 - loss: 1.5196
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8755 - loss: 0.4425
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9030 - loss: 0.3302
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9114 - loss: 0.2969
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.5486 - loss: 1.4752
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8664 - loss: 0.4453
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9042 - loss: 0.3168
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9177 - loss: 0.2921
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.5422 - loss: 1.5222
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8683 - loss: 0.4484
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9247 - loss: 0.2928
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9156 - loss: 0.2991
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.3115 - loss: 2.0379
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6452 - loss: 1.3026
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7219 - loss: 1.0661
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.7948 - loss: 0.7712
# Epoch 1/3
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.1204 - loss: 2.3287
# Epoch 2/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3733 - loss: 2.0904
# Epoch 3/3
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5463 - loss: 1.5854
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.7334 - loss: 1.1803

# %% [markdown]
# ## Show best result

# %%
neurons, activation, dropout = decode_particle(gbest)
print("Best Architecture Found:")
print("Neurons per layer:", neurons)
print("Activation:", activation)
print("Dropout:", dropout)
print("Validation Accuracy:", -gbest_fitness)
# Out:
# Best Architecture Found:
# Neurons per layer: [125, 153, 92]
# Activation: tanh
# Dropout: 0.13179422287244963
# Validation Accuracy: 0.925000011920929
